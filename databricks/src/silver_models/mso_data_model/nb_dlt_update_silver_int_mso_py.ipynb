# %%
import dlt
from mdp_databricks_common.sql.sql_loader import SQLLoader
from mdp_databricks_common.utils.data_load_utils import get_asset_bundle_root_path

env_var = dbutils.secrets.get(scope = 'data-kv-scope', key = 'data-platform-environment')
job_name = "MSO"

# %% [markdown]
# #MSO Automated Valuation Model

# %%
expectations = {
    "primary_keys_are_not_null": "AUTOMATED_VALUATION_MODEL_ID IS NOT NULL ",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_automated_valuation_model",
    comment="Silver Layer table for MSO Automated Valuation Model."
)
@dlt.expect_all_or_drop(expectations)
def silver_int_mso_automated_valuation_model():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/internal/mso_automated_valuation_model.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Loan Requirement

# %%
expectations = {
    "primary_keys_are_not_null": "LOAN_REQUIREMENT_ID IS NOT NULL",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_loan_requirement",
    comment="Silver Layer table for MSO Loan Requirement."
)
@dlt.expect_all_or_drop(expectations)
def silver_int_mso_automated_valuation_model():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/internal/mso_loan_requirement.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# # MSO Offer Version Condition

# %%
expectations = {
    "primary_keys_are_not_null": (
        "OFFER_ID IS NOT NULL "
        "AND VERSION_NUMBER IS NOT NULL "
        "AND REFERENCE IS NOT NULL"
    ),
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_offer_version_condition",
    comment="Silver Layer table for MSO Offer Version Condition. One row per offer condition."
)
@dlt.expect_all_or_drop(expectations)
def silver_int_mso_offer_version_condition():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/internal/mso_offer_version_condition.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# # MSO Remittance

# %%
expectations = {
    "primary_keys_are_not_null": "REMITTANCE_ID IS NOT NULL",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_remittance",
    comment="Silver Layer table for MSO remittance."
)
@dlt.expect_all_or_drop(expectations)
def silver_int_mso_remittance():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/internal/mso_remittance.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Repayment Strategy

# %%
expectations = {
    "primary_keys_are_not_null": (
        "LOAN_REQUIREMENT_ID IS NOT NULL "
        "AND STRATEGY_TYPE IS NOT NULL"
    ),
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_repayment_strategy",
    comment="Silver Layer table for MSO Repayment Strategy. One row per case."
)
@dlt.expect_all_or_drop(expectations)
def silver_int_mso_repayment_strategy():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/internal/mso_repayment_strategy.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Selected Product

# %%
expectations = {
    "primary_keys_are_not_null": (
        "CASE_ID IS NOT NULL "
        "AND PRODUCT_ID IS NOT NULL "
        "AND TERM_IN_MONTHS IS NOT NULL"
    ),
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_selected_product",
    comment="Silver Layer table for MSO Selected Product. One row per case part."
)
@dlt.expect_all_or_drop(expectations)
def silver_int_mso_selected_product():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/internal/mso_selected_product.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Selected Product Value

# %%
expectations = {
    "primary_keys_are_not_null": "SELECTED_PRODUCT_VALUE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_selected_product_value",
    comment="Silver Layer table for MSO Selected Product Value."
)
@dlt.expect_all_or_drop(expectations)
def silver_int_mso_selected_product_value():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/internal/mso_selected_product_value.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Valuation Report

# %%
expectations = {
    "primary_keys_are_not_null": "VALUATION_REPORT_ID IS NOT NULL",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_valuation_report",
    comment="Silver Layer table for MSO valuation report."
)
@dlt.expect_all_or_drop(expectations)
def silver_int_mso_valuation_report():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/internal/mso_valuation_report.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Valuation Report Detail

# %%
expectations = {
    "primary_keys_are_not_null": "VALUATION_REPORT_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_valuation_report_detail",
    comment="Silver Layer table for MSO valuation report detail."
)
@dlt.expect_all_or_drop(expectations)
def silver_int_mso_valuation_report_detail():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/internal/mso_valuation_report_detail.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )
