# %%
import dlt
from mdp_databricks_common.sql.sql_loader import SQLLoader
from mdp_databricks_common.utils.data_load_utils import get_asset_bundle_root_path

env_var = dbutils.secrets.get(scope = 'data-kv-scope', key = 'data-platform-environment')
job_name = "MSO"

# %% [markdown]
# #MSO Case

# %%
expectations = {
    "primary_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_case",
    comment="Silver Layer table for MSO Case. One row per case."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_case():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/mso_case.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Case Event

# %%
expectations = {
    "primary_keys_are_not_null": "CASE_EVENT_ID IS NOT NULL",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_case_event",
    comment="Silver Layer table for MSO Case Event. One row per case event."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_case_event():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/mso_case_event.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Valuation Report Status History

# %%
expectations = {
    "primary_keys_are_not_null": "VALUATION_REPORT_STATUS_HISTORY_ID IS NOT NULL",
    "foreign_keys_are_not_null": "VALUATION_REPORT_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_valuation_report_status_history",
    comment="Silver Layer table for MSO Valuation Report Status History."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_valuation_report_status_history():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/mso_valuation_report_status_history.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Advisor

# %%
expectations = {
    "primary_keys_are_not_null": "ADVISOR_ID IS NOT NULL",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_advisor",
    comment="Silver Layer table for MSO Advisor. One row per advisor."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_advisor():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/advisor.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Applicant

# %%
expectations = {
    "primary_keys_are_not_null": "APPLICANT_ID IS NOT NULL",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_applicant",
    comment="Silver Layer table for MSO Applicant. One row per applicant."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_applicant():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/applicant.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Applicant Address

# %%
expectations = {
    "primary_keys_are_not_null": "APPLICANT_ADDRESS_ID IS NOT NULL",
    "foreign_keys_are_not_null": "APPLICANT_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_applicant_address",
    comment="Silver Layer table for MSO Applicant Address. One row per address."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_applicant_address():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/applicant_address.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Committed Expenditure

# %%
expectations = {
    "primary_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_committed_expenditure",
    comment="Silver Layer table for MSO Committed Expenditure. One row per financial commitment."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_committed_expenditure():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/committed_expenditure.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Committed Expenditure Value

# %%
expectations = {
    "primary_keys_are_not_null": "COMMITTED_EXPENDITURE_VALUE_ID IS NOT NULL",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_committed_expenditure_value",
    comment="Silver Layer table for MSO Committed Expenditure value. One row per financial commitment."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_committed_expenditure_value():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/committed_expenditure_value.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Decline Appeal

# %%
expectations = {
    "primary_keys_are_not_null": "DECLINE_APPEAL_ID IS NOT NULL",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL AND DECISION_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_decline_appeal",
    comment="Silver Layer table for MSO Decline Appeal. One row per appeal."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_decline_appeal():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/decline_appeal.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Deleted Record

# %%
expectations = {
    "primary_keys_are_not_null": "KEY_NAME_1 IS NOT NULL AND KEY_VALUE_1 IS NOT NULL",
    "deleted_date_is_not_null": "DATE_DELETED_FROM_PUBLISHED IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_deleted_record",
    comment="Silver Layer table for MSO Deleted record. One row per purged case."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_deleted_record():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/deleted_record.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Deleted Record Key Value Store

# %%
expectations = {
    "primary_keys_are_not_null": "TABLE_NAME IS NOT NULL",
    "deleted_date_is_not_null": "DATE_DELETED_FROM_PUBLISHED IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_deleted_record_key_value_store",
    comment="Silver Layer table for MSO Deleted record key value store. One row per key value pair, per purged case."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_deleted_record_kvs():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/deleted_record_key_value_store.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Employment Income Value

# %%
expectations = {
    "primary_keys_are_not_null": "EMPLOYMENT_INCOME_VALUE_ID IS NOT NULL",
    "foreign_keys_are_not_nukk": "APPLICANT_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_employment_income_value",
    comment="Silver Layer table for MSO employment income value. One row per applicant."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_employment_income_value():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/employment_income_value.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Existing Property Address

# %%
expectations = {
    "primary_keys_are_not_null": "EXISTING_PROPERTY_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_existing_property_address",
    comment="Silver Layer table for MSO existing_property_address. One row per address."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_existing_property_address():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/existing_property_address.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Existing Property Applicant

# %%
expectations = {
    "foreign_keys_are_not_null": "EXISTING_PROPERTY_ID IS NOT NULL AND APPLICANT_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_existing_property_applicant",
    comment="Silver Layer table for MSO existing proeprty applicant. Bridges existing properties to applicants. One row per applicant per address."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_existing_property_applicant():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/existing_property_applicant.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Fee Transaction

# %%
expectations = {
    "primary_keys_are_not_null": "FEE_TRANSACTION_ID IS NOT NULL",
    "foreign_keys_are_not_null": "FEE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_fee_transaction",
    comment="Silver Layer table for MSO fee transaction. One row per transaction."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_fee_transaction():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/fee_transaction.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Firm

# %%
expectations = {
    "primary_keys_are_not_null": "FIRM_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_firm",
    comment="Silver Layer table for MSO firm. One row per intermediary firm."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_firm():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/firm.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Identity Verification Document

# %%
expectations = {
    "primary_keys_are_not_null": "IDENTITY_VERIFICATION_DOCUMENT_ID IS NOT NULL",
    "foreign_keys_are_not_null": "APPLICANT_ID IS NOT NULL AND ASSET_VERSION_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_identity_verification_document",
    comment="Silver Layer table for MSO identity_verification_document. One row per document."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_identity_verification_document():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/identity_verification_document.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Intermediary

# %%
expectations = {
    "primary_keys_are_not_null": "INTERMEDIARY_ID IS NOT NULL",
    "foreign_keys_are_not_null": "FIRM_ID IS NOT NULL AND TRADING_ADDRESS_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_intermediary",
    comment="Silver Layer table for MSO intermediary. One row per intermediary."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_intermediary():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/intermediary.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Originations User (MEMBER)
# This is driven by the `MEMBER` table but we have renamed it so as not to cause confusion between an Originations User and an actual Member.

# %%
expectations = {
    "primary_keys_are_not_null": "ORIGINATIONS_USER_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_originations_user",
    comment=(
        "Silver Layer table for MSO originations user. One row per user. "
        "This table is driven by the MSO MEMBER table but we have renamed it so that we don't"
        " confuse MSO Member (originations user) with an actual society member."
    )
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_originations_user():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/originations_user.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Need and Circumstance

# %%
expectations = {
    "primary_keys_are_not_null": "NEED_AND_CIRCUMSTANCE_ID IS NOT NULL",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_need_and_circumstance",
    comment="Silver Layer table for MSO need and circumstance. One row per question."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_need_circumstance():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/need_and_circumstance.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Originations Case Owner

# %%
expectations = {
    "primary_keys_are_not_null": "ORIGINATIONS_CASE_OWNER_ID IS NOT NULL",
    "foreign_keys_are_not_null": "CASE_ID IS NOT NULL AND OWNER_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_originations_case_owner",
    comment="Silver Layer table for MSO originations case owner. One row per owner."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_originations_case_owner():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/originations_case_owner.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )

# %% [markdown]
# #MSO Payment Route

# %%
expectations = {
    "primary_keys_are_not_null": "PAYMENT_ROUTE_ID IS NOT NULL",
    "watermark_is_not_null": "LAST_UPDATED_DATETIME IS NOT NULL",
    "row_hash_is_not_null": "MDP_ROW_HASH IS NOT NULL"
}

@dlt.table(
    name="mso_payment_route",
    comment="Silver Layer table for MSO payment route. One row per payment route."
)
@dlt.expect_all_or_drop(expectations)
def silver_con_mso_payment_route():
    sl = SQLLoader(
        environment_name=env_var,
        target_path=(
            f"{get_asset_bundle_root_path(env_var)}"
            "files/src/silver_models/mso_data_model"
            "/sql_scripts/silver/confidential/payment_route.sql"
        ),
        replacements=None
    )
    return spark.sql(
        sl.load()
    )
