# %%
# Install a version of common-libs which has local-time functions in. (3.4.9)
# %pip install '/Volumes/dev_catalog/common_libraries/mdp_databricks_common_3_4_9/mdp_databricks_common-3.4.9-py3-none-any.whl'
dbutils.library.restartPython()

# %% [markdown]
# ### Before importing the alias function...

# %%
from datetime import datetime
my_time = datetime.now()
print(my_time)

# %% [markdown]
# ### Now import the get_local_time() function and demonstrate its use...

# %%
from mdp_databricks_common.utils.time_utils import get_local_time
my_local_time = get_local_time()
print(my_local_time)

# %% [markdown]
# ### Before setting local time in the spark session...

# %%
spark.sql("select current_timestamp()").display()

# %% [markdown]
# ### Now pull in the enable_local_time_in_spark_session() function and demonstrate its use...

# %%
from mdp_databricks_common.utils.time_utils import enable_local_time_in_spark_session

enable_local_time_in_spark_session()
spark.sql("select current_timestamp()").display()
